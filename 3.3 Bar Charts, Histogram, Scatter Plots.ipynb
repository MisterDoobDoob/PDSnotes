# %% [markdown]
# ### Pie Charts
# Pie Charts can be plotted with ```plt.pie()```

# %%
# pie chart - values
import matplotlib.pyplot as plt

mathMarks = [70,30,40,90,10]
plt.pie(mathMarks)

plt.show()

# %%
# pie chart - values + labels
import matplotlib.pyplot as plt

mathMarks = [70,30,40,90,10]
student = ('Tom', 'Dick', 'Harry', 'Sally', 'Sue')


plt.pie(mathMarks, labels = student)

#Include %Share
#plt.pie(mathMarks, labels = student, autopct='%1.1f%%') 

plt.show()

# %%
# pie chart - values + labels + %share + title + explore
import matplotlib.pyplot as plt

mathMarks = [70,30,40,90,10]
student = ('Tom', 'Dick', 'Harry', 'Sally', 'Sue')
explode = (0,0,0,0.1,0)
plt.pie(mathMarks, labels = student, autopct='%1.1f%%', explode = (0,0,0,0.1,0) )
plt.title("Math Test Score")
plt.show()

# %% [markdown]
# ##### But hold on, this isn't a very good way to visualise the marks of the students!<br>
# Pie charts are great for things that add up to 100%, or add up to a "whole". In this case, adding up the marks of each students doesn't add up to a whole.<br>
#
# Let's look at a better application of a bar chart.

# %%
# pie chart - plot grades
import matplotlib.pyplot as plt

gradePoint = ["A1", "A2", "B3", "C5", "F9" ]
grades = (3,8,6,3,1)
explode = (0,0.05,0,0,0)
plt.pie(grades, labels = gradePoint, autopct='%1.1f%%', explode = explode)
plt.title("Math Test Grades")
plt.show()

# %%
import matplotlib.pyplot as plt

# Slices are ordered, anti-clockwise
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0) # Explode 2nd

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)

# Eq aspect ratio draws pie as circle
ax1.axis('equal')
plt.show()

# %%
import matplotlib.pyplot as plt

# Slices are ordered, anti-clockwise
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0) # Explode 2nd

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)

# Eq aspect ratio draws pie as circle
ax1.axis('equal')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Slices are ordered, anti-clockwise
classB = np.array([["A1","A2","B3","B4","C5","C6","F9"],
                 [30,75,70,53,30,10,10]])

labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]

explode = (0, 0.1, 0, 0) # Explode 2nd

fig1, ax1 = plt.subplots()
ax1.pie(classB[1], labels=classB[0], autopct='%1.0f%%',
        shadow=True, startangle=90)

# Eq aspect ratio draws pie as circle
ax1.axis('scaled')
plt.show()

# %% [markdown]
# ### Histogram
# Good for continuous or "flowing" data

# %%
# Histogram Example
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

gaussian_numbers = np.random.randn(1000)
plt.hist(gaussian_numbers)

plt.title("Gaussian Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")

plt.show()

# %%
# Histogram
import matplotlib.pyplot as plt
salary = (506,507,503,508,511,500,513,506,507,504,509,508,509,510,511,506,504,507,501,500,502,503,502,501)
plt.hist(salary)
plt.show()

# %%
sala# Histogram Eg 2
import numpy as np
import matplotlib.pyplot as plt

#read in the dataset
data = np.genfromtxt("data/coe-results.csv",
            delimiter=',',
            names=True, dtype=('U7',int,'U10',int,int,int,int))

#set up the values
catA = data[data['vehicle_class'] == 'Category A']['quota']

#label the plot
plt.title('Distribution of Category A Quota')
plt.xlabel('Quota')
plt.ylabel('Frequency')

#plot the histogram
plt.hist(catA)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-2165904e308e> in <module>
#      17
#      18 #plot the histogram
# ---> 19 plt.scatter(catA)
#      20 plt.show()
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %% [markdown]
# ### Scatter Plot
# sdasdad

# %%
# Scatter Plot (random, no correlation)
import numpy as np
import matplotlib.pyplot as plt

x = np.random.randn(100)
y = np.random.randn(100)

plt.scatter(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

#read in the dataset
data = np.genfromtxt("data/coe-results.csv",
            delimiter=',',
            names=True, 
            dtype=('U7',int,'U10',int,int,int,int))


#set up the values
catA = data[data['vehicle_class'] == 'Category A']['quota']
catB = data[data['vehicle_class'] == 'Category B']['quota']

#label the plot
plt.title('Correlation between Category A Quota and Category B Quota')
plt.xlabel('Category A Quota')
plt.ylabel('Category B Quota')

#plot the scatter plot
plt.scatter(catA, catB)
plt.show()

# %% [markdown]
# From the data above, we can tell that category A and B generally scale linearly

# %%
# Student Scores
import matplotlib.pyplot as plt
math = (64,65,60,58,84,76,59,54,60)
science = (69,70,76,67,54,78,76,57,78)
plt.scatter(math,science)
plt.xlabel("Math Score")
plt.ylabel("Science Score")
plt.text(82,55, "outlier", style = "italic", 
         bbox={"facecolor":"green", "alpha":0.2, "pad":3})
plt.title("RS between math and science test score")
plt.show()

# %%
# Ice Creame
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Bar Charts
# Best for "discrete" data, where each piece of data is not directly linked to one another
